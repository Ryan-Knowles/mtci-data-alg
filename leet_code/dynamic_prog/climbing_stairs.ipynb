# %% [markdown]
# # Climbing Stairs [easy]
#
# Source: https://leetcode.com/problems/climbing-stairs/description/
#
# You are climbing a staircase. It takes n steps to reach the top.
#
# Each time you can either climb 1 or 2 steps. In how many distinct ways can you climb to the top?
#
# ## Example 1:
#
# Input: n = 2
#
# Output: 2
#
# Explanation: There are two ways to climb to the top.
# 1. 1 step + 1 step
# 2. 2 steps
#
# ## Example 2:
#
# Input: n = 3
#
# Output: 3
#
# Explanation: There are three ways to climb to the top.
# 1. 1 step + 1 step + 1 step
# 2. 1 step + 2 steps
# 3. 2 steps + 1 step
#
#
# ## Constraints:
#
# - 1 <= n <= 45

# %%
class Solution:
    def __init__(self):
        # Kickstart the memo with some values
        self.memo = {
            0: 0,
            1: 1,
            2: 2,
            3: 3,
            4: 5
        }

    def reset(self):
        # Kickstart the memo with some values
        self.memo = {
            0: 0,
            1: 1,
            2: 2,
            3: 3,
            4: 5
        }

    def climbStairs(self, n: int) -> int:

        # Base cases + check cache
        if n in self.memo:
            return self.memo[n]

        # If we take one step last, it will be this many values
        one_step = self.climbStairs(n-1) 

        # If we take two steps, we will be coming from n-2 so it will be this many values
        two_step = self.climbStairs(n-2)

        self.memo[n] = one_step + two_step
        return self.memo[n]

# %%
# Test cases
solution = Solution()




# Test case 1: n = 1
solution.reset()
assert solution.climbStairs(1) == 1
print("Test case 1 passed!")

# Test case 2: n = 2
solution.reset()
assert solution.climbStairs(2) == 2
print("Test case 2 passed!")

# Test case 3: n = 3
solution.reset()
assert solution.climbStairs(3) == 3
print("Test case 3 passed!")

# Test case 4: n = 4
solution.reset()
assert solution.climbStairs(4) == 5
print("Test case 4 passed!")

# Test case 5: n = 5
solution.reset()  # Reset memo to ensure we're testing the function logic
result = solution.climbStairs(5)
assert result == 8, f"Expected 8 for n=5, but got {result}"
print("Test case 5 passed!")

# Test case 6: n = 10
solution.reset()
result = solution.climbStairs(10)
assert result == 89, f"Expected 89 for n=10, but got {result}"
print("Test case 6 passed!")

# Test case 7: Edge case - minimum constraint
solution.reset()
assert solution.climbStairs(1) == 1
print("Test case 7 passed!")

# Note: Testing n = 45 (maximum constraint) would be valid
# but might take too long depending on implementation

print("All test cases passed!\n\n")

# Test with larger values
print("Testing larger values...")
solution.reset()

# Known Fibonacci sequence values for stairs
expected_values = {
    5: 8,
    6: 13,
    7: 21,
    8: 34,
    10: 89,
    15: 987,
    20: 10946,
    30: 1346269,
    40: 165580141,
    45: 1836311903
}

# Test several values up to n=45 (the constraint maximum)
for n, expected in expected_values.items():
    result = solution.climbStairs(n)
    assert result == expected, f"For n={n}, expected {expected} but got {result}"
    print(f"n={n}: {result} ways to climb ✓")

print("All large test cases passed!")
# Out:
# Test case 1 passed!
# Test case 2 passed!
# Test case 3 passed!
# Test case 4 passed!
# Test case 5 passed!
# Test case 6 passed!
# Test case 7 passed!
# All test cases passed!
#
#
# Testing larger values...
# n=5: 8 ways to climb ✓
# n=6: 13 ways to climb ✓
# n=7: 21 ways to climb ✓
# n=8: 34 ways to climb ✓
# n=10: 89 ways to climb ✓
# n=15: 987 ways to climb ✓
# n=20: 10946 ways to climb ✓
# n=30: 1346269 ways to climb ✓
# n=40: 165580141 ways to climb ✓
# n=45: 1836311903 ways to climb ✓
# All large test cases passed!
